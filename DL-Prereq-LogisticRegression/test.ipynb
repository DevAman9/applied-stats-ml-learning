# %% [markdown]
# # Testing Myself on logistic regression.

# %% [markdown]
# 1: It is supervised learning because the structure of the data and the output Y is given to us. we have clear inputs and outputs which we can use to train and test. ; it is classification because the output is in categories. its either 0 or 1. and not a range of integers which we have to predict from. one row of x represents one person. and one element of y represents the outcome or prediction made on for that specific row of inputs or that specific person.
# 2: alright z would be 1 + 2 = 3. the dot product would be 1. and b is 2. so 3 would be the answer.
# 3: because z is just a linear function it doesnt provide output as probability between 0 and 1. sigmoid is 1/1 + e^-z. and since its 1 as a numerator, the answer would be between 0 and 1. which could be taken as a probability.
# 4: p = 0.82 in binary logic would be mean 82% chance of it being 1. so we would select 1 as the prediction.
# 5: sigmoid returns 0.5 or 1/2 when the input is 0. meaning its the middle classification line. it represents the decision boundary because it divides the probabilities in half.
# 6: bias is error or noise in the data. we add bias to account for external influences in the data. the first z is the formal linear function way where b is added onto the weights. but the second one, b is used as a dummy variable and its 1, so it gets calculated along with weight calculation as well.
# 7: [1, 3, 2.4, 0, 0, 0, 1, 0]
# 8: we cant leave the time as just 0, 1, 2, and 3 because they are categories and the algorithm doesnt know what they represent. that's why when we distribute them across multiple columsn, the pattern becomes easier to compile and comprehend.
# 9: N = 327, D = 8, W.shape = 8. but do we add dummy variable in W???? then 9. Xtrain.dot(w).shape =;; but it represents the z for one individual row.
# 10: no clue.
# 11: [True, False, True, False, True, True], 0, 2, 4, 5

# %%
import numpy as np


x = np.array([2, 5])
W = np.array([3, -1])
b = 2

# %%
print(x.dot(W))
print(W)
print(x)
# Out:
# 1
# [ 3 -1]
# [2 5]

# %%
def sigmoid(z):
    return 1 / 1 + np.exp(-z) # need brackets around the 1 + np.exp(-z)

def forward(X, W, b):
    return X.dot(W) + b #needed sigmoid function here.

def classification_rate(Y, P):
    return # i know its something to do with mean but i am not sure what it even means. i think the success rate.
# okay classification rate is the mean Y matching with P . like if 3/4 match then boom. 0.75% classication rate.

# %%
predictions = np.round(probabilities)

# %% [markdown]
# dont be too harsh. you didnt give me any revision. i am weak at coding and i still dont understand so much. like actually. i am very weak trust. but nah. move on.

# %% [markdown]
# # New test

# %%
def sigmoid(z):
    return 1 / (1 + np.exp(-z))

def forward(X, W, b):
    return sigmoid(X.dot(W) + b)

def cross_entropy(T, p):
#     E = 0
#     for i in range(N):
#         if T[i] == 1:
#             E -= np.log(p)
#         else:
#             E -= np.log(1 - p)
#     return E
# # i dont know the vectorised cross entropy version but imma try. easy

    return -np.mean(T*np.log(p) + (1-T)*np.log(1-p))

def classification_rate(T, predictions):
    return np.mean(T == predictions)

# %%
# nah this is the part i am the most confused about. since i dont even know what code goes in here. its too complicated. i know we use training and testing data but lazy programmer doesnt actually explain it very well. i didnt quite understand what codes to use. like sure i know the formula for gradient descent and all that but still.
learning_rate = 0.001

for i in range(10000):

    # A: probabilities on training set


    # B: probabilities on test set


    # C: update W using TRAINING DATA ONLY


    # D: update b using TRAINING DATA ONLY

# %% [markdown]
# I didnt actually understand the testing part at all. the gradient descent and training part was so short and i didnt understand . lazy programmer actuallly didnt do a great job explaining them. i dunno. i am still pretty blurry on them. but i wanna move on and do the facial recognition one so i can understand better. i didnt even know we had a test cost. i didnt even know we had a traning cost. wtf. like actually. i am so pissed and wanna punch my laptop on me being such a dumbass. like actually why is my brain so 20 iq. i bet a random unc can understand this better.

# %%
learning_rate = 0.001

for i in range(10000):

    # predictions using current weights
    pYtrain = forward(Xtrain, W, b)
    pYtest = forward(Xtest, W, b)

    # measure current performance
    ctrain = cross_entropy(Ytrain, pYtrain)
    ctest = cross_entropy(Ytest, pYtest)

    # TRAINING HAPPENS HERE
    W -= learning_rate * Xtrain.T.dot(pYtrain - Ytrain)
    b -= learning_rate * (pYtrain - Ytrain).sum()

# %% [markdown]
# Last test. check .

# %% [markdown]
# 1: from raw data. we distribute the data into training and test. and also X and Y inside each training and testing data . after that we just make the weight vector to calculate weights (assuming we use a dummy variable for bias ) and store them. then we calculate z and pass it into the sigmoid function to get the probabilities. then for the training part we just set a loop for desired amount, predict the probabilites of training and test. and then we get the cross entropy of both and then we only train using the training data. we use gradient descent to update W and B everytime. and yeah.
# 2:

# %%
def sigmoid(z):
    return 1 / (1 + np.exp(-z))

def forward(X, W, b):
    return sigmoid(X.dot(W) + b)

def cross_entropy(T, p):
    return -np.mean(T * np.log(p) + (1 - T) * np.log(1 - p))

# %%
W -= learning_rate * Xtrain.T.dot(ptrain - Ytrain)
b -= learning_rate * (ptrain - Ytrain).sum()

# %% [markdown]
# test set is to test the fucntion on. we see how our updated weights and bias perform on the test data. we dont use it to train.
# L2 regularistion forces the algorithm to brings weights to very small values. it basically squares the weights while penalising them.
# logistic regresssion solve the donut/XOR problem even because the x or the data points can be presented or represented in a different way. one way they look covered all over by same data points, but using just a centre point reference immediately seperates the data.
